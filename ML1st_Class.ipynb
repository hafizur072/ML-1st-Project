# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizur072/ML-1st-Project/blob/main/ML1st_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome** **program**

# %%
print("Assalamualaikum, welcome to skill morph")
# Out:
# Assalamualaikum, welcome to skill morph

# %% [markdown]
# # **My Profile**

# %% [markdown]
# ## **My Introduction**

# %%
print("My name is Md. Hafizur Rahman")
# Out:
# My name is Md. Hafizur Rahman

# %%
print("I am an Assistant Professor in Human Resource Management at Bangladesh Army University of Engineering & Technology (BAUET), Qadirabad Cantonment, Natore")
# Out:
# I am an Assistant Professor in Human Resource Management at Bangladesh Army University of Engineering & Technology (BAUET), Qadirabad Cantonment, Natore

# %% [markdown]
# ## **My Research Works**

# %%
print("1. Influence of teachers emotional intelligence on students motivation for academic learning- an empirical study on university students of Bangladesh")
# Out:
# 1. Influence of teachers emotional intelligence on students motivation for academic learning- an empirical study on university students of Bangladesh

# %%
print(" 2. The Impact of Green Management System on Employee Work Performance: Evidence from Consumer Products in Bangladesh")
# Out:
#  2. The Impact of Green Management System on Employee Work Performance: Evidence from Consumer Products in Bangladesh

# %%
print("3. Contributions of Green Supply Chain Management on Perceived Firm Performance: An Empirical Investigation of the FMCG Industry in Bangladesh")
# Out:
# 3. Contributions of Green Supply Chain Management on Perceived Firm Performance: An Empirical Investigation of the FMCG Industry in Bangladesh

# %%
print("4. Factors affecting university students intention towards halalpreneurship: An empirical study on university students of Bangladesh")
# Out:
# 4. Factors affecting university students intention towards halalpreneurship: An empirical study on university students of Bangladesh

# %%
print("5. Strategies for Promoting Universities in South Asian Region: A Review of Contemporary Literature")
# Out:
# 5. Strategies for Promoting Universities in South Asian Region: A Review of Contemporary Literature

# %%
print("6. The Nexus Among Employees' Green Concerns, Green Effectiveness, and Green Behavior Through Mediating Role of Employees' Green Knowledge: Evidence from Bangladeshi Consumer Goods Industry")
# Out:
# 6. The Nexus Among Employees' Green Concerns, Green Effectiveness, and Green Behavior Through Mediating Role of Employees' Green Knowledge: Evidence from Bangladeshi Consumer Goods Industry

# %% [markdown]
# # **Thank you for visiting my profile**
